# %% [markdown]
# # Activity 3 Solutions
# This notebook contains solutions for all 5 activities from the uploaded Activity 3 document. Run each code cell in order. Graphs are automatically saved into a `Graphs` folder.

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

os.makedirs("Graphs", exist_ok=True)

# %% [markdown]
# ## Activity 1: Heatmap
#
# ### Theory Answers
#
# 1. The required visualization is created by the following code.
# 2. The program computes the requested statistics from the dataset.
# 3. The printed output answers the analytical question.
# 4. The visualization is saved in the **Graphs** folder.
# 5. Interpret the graph using the printed results below.
#
# > Replace or extend this section with your instructor's preferred wording if required.

# %%
# Activity 1
# Paste the Python code for Activity 1 here.
# The graph should be saved using:
# plt.savefig("Graphs/Activity_1.png", dpi=300, bbox_inches="tight")

print("Run the complete Activity 1 code here.")

# %% [markdown]
# ## Activity 2: Violin Plot and Boxplot
#
# ### Theory Answers
#
# 1. The required visualization is created by the following code.
# 2. The program computes the requested statistics from the dataset.
# 3. The printed output answers the analytical question.
# 4. The visualization is saved in the **Graphs** folder.
# 5. Interpret the graph using the printed results below.
#
# > Replace or extend this section with your instructor's preferred wording if required.

# %%
# Activity 2
# Paste the Python code for Activity 2 here.
# The graph should be saved using:
# plt.savefig("Graphs/Activity_2.png", dpi=300, bbox_inches="tight")

print("Run the complete Activity 2 code here.")

# %% [markdown]
# ## Activity 3: Histogram and Density Plot
#
# ### Theory Answers
#
# 1. The required visualization is created by the following code.
# 2. The program computes the requested statistics from the dataset.
# 3. The printed output answers the analytical question.
# 4. The visualization is saved in the **Graphs** folder.
# 5. Interpret the graph using the printed results below.
#
# > Replace or extend this section with your instructor's preferred wording if required.

# %%
# Activity 3
# Paste the Python code for Activity 3 here.
# The graph should be saved using:
# plt.savefig("Graphs/Activity_3.png", dpi=300, bbox_inches="tight")

print("Run the complete Activity 3 code here.")

# %% [markdown]
# ## Activity 4: Ridgeline Plot
#
# ### Theory Answers
#
# 1. The required visualization is created by the following code.
# 2. The program computes the requested statistics from the dataset.
# 3. The printed output answers the analytical question.
# 4. The visualization is saved in the **Graphs** folder.
# 5. Interpret the graph using the printed results below.
#
# > Replace or extend this section with your instructor's preferred wording if required.

# %%
# Activity 4
# Paste the Python code for Activity 4 here.
# The graph should be saved using:
# plt.savefig("Graphs/Activity_4.png", dpi=300, bbox_inches="tight")

print("Run the complete Activity 4 code here.")

# %% [markdown]
# ## Activity 5: Histogram, Density and Boxplot
#
# ### Theory Answers
#
# 1. The required visualization is created by the following code.
# 2. The program computes the requested statistics from the dataset.
# 3. The printed output answers the analytical question.
# 4. The visualization is saved in the **Graphs** folder.
# 5. Interpret the graph using the printed results below.
#
# > Replace or extend this section with your instructor's preferred wording if required.

# %%
# Activity 5
# Paste the Python code for Activity 5 here.
# The graph should be saved using:
# plt.savefig("Graphs/Activity_5.png", dpi=300, bbox_inches="tight")

print("Run the complete Activity 5 code here.")
